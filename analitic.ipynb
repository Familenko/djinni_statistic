# %%
import pandas as pd

# %%
df = pd.read_csv('db.csv')

# %%
df.sample(50)
# Out:
#                                                  Title  Company  \
# 165                         Software Engineer (Python)      NaN
# 140                                   Lead AI Engineer      NaN
# 40                           Python (Django) Developer      NaN
# 11   Python Developer (Разработчик бота у криптосер...      NaN
# 142   Senior Full Stack Software Developer (Python+JS)      NaN
# 122                            IoT developer (LoRaWAN)      NaN
# 135                            Senior Python Developer      NaN
# 56                                    Python Developer      NaN
# 178                            Senior Python Developer      NaN
# 175                                              Title  Company
# 96                            Python (Django) Engineer      NaN
# 109                            Senior Python Developer      NaN
# 65             Open Omniverse UI / Extension developer      NaN
# 155                                   Python Developer      NaN
# ...
